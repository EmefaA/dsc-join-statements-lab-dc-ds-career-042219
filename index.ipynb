# %% [markdown]
# # Join Statements - Lab
#
# ## Introduction
#
# In this lab, you'll practice your knowledge of join statements, using various types of joins and various methods for specifying the links between them.
#
# ## Objectives
#
# You will be able to:
# - Write queries that make use of various types of Joins
# - Join tables using foreign keys

# %% [markdown]
# ## CRM Schema
#
# In almost all cases, rather then just working with a single table you will typically need data from multiple tables.
# Doing this requires the use of **joins ** using shared columns from the two tables.
#
# In this lab, you'll use the same Customer Relationship Management (CRM) database that you saw from the previous lesson.
# <img src='images/Database-Schema.png' width="600">

# %% [markdown]
# ## Connecting to the Database
# Import the necessary packages and connect to the database **data.sqlite**.

# %%
#Your code here
import pandas as pd
import sqlite3
conn = sqlite3.connect('data.sqlite', detect_types=sqlite3.PARSE_COLNAMES)
cur = conn.cursor()

# %% [markdown]
# ## Display the names of all the employees in Boston.
# Hint: join the employees and customers tables.

# %%
#Your code here
cur.execute("""select * from employees
                        LEFT JOIN offices
                        on employees.officeCode = offices.officeCode
                        WHERE city = 'Boston';
                       """)
df = pd.DataFrame(cur.fetchall()) #Take results and create dataframe
df.columns = [i[0] for i in cur.description]
df
# Out:
#   employeeNumber   lastName firstName extension  \
# 0           1188   Firrelli     Julie     x2173
# 1           1216  Patterson     Steve     x4334
#
#                              email officeCode reportsTo   jobTitle officeCode  \
# 0   jfirrelli@classicmodelcars.com          2      1143  Sales Rep          2
# 1  spatterson@classicmodelcars.com          2      1143  Sales Rep          2
#
#      city            phone      addressLine1 addressLine2 state country  \
# 0  Boston  +1 215 837 0825  1550 Court Place    Suite 102    MA     USA
# 1  Boston  +1 215 837 0825  1550 Court Place    Suite 102    MA     USA
#
#   postalCode territory
# 0      02107        NA
# 1      02107        NA

# %% [markdown]
# ## Do any offices have no employees?
# Hint: Combine the employees and offices tables and use a group by.

# %%
#Your code here
cur.execute("""select * from offices
                        LEFT JOIN employees
                        on offices.officeCode = employees.officeCode
                        ORDER BY city;
                       """)
df = pd.DataFrame(cur.fetchall()) #Take results and create dataframe
df.columns = [i[0] for i in cur.description]
df
# Out:
#    officeCode           city             phone              addressLine1  \
# 0           2         Boston   +1 215 837 0825          1550 Court Place
# 1           2         Boston   +1 215 837 0825          1550 Court Place
# 2           7         London  +44 20 7877 2041       25 Old Broad Street
# 3           7         London  +44 20 7877 2041       25 Old Broad Street
# 4           3            NYC   +1 212 555 3000      523 East 53rd Street
# 5           3            NYC   +1 212 555 3000      523 East 53rd Street
# 6           4          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# 7           4          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# 8           4          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# 9           4          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# 10          4          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# 11          1  San Francisco   +1 650 219 4782         100 Market Street
# 12          1  San Francisco   +1 650 219 4782         100 Market Street
# 13          1  San Francisco   +1 650 219 4782         100 Market Street
# 14          1  San Francisco   +1 650 219 4782         100 Market Street
# 15          1  San Francisco   +1 650 219 4782         100 Market Street
# 16          1  San Francisco   +1 650 219 4782         100 Market Street
# 17          6         Sydney   +61 2 9264 2451     5-11 Wentworth Avenue
# 18          6         Sydney   +61 2 9264 2451     5-11 Wentworth Avenue
# 19          6         Sydney   +61 2 9264 2451     5-11 Wentworth Avenue
# 20          6         Sydney   +61 2 9264 2451     5-11 Wentworth Avenue
# 21          5          Tokyo   +81 33 224 5000               4-1 Kioicho
# 22          5          Tokyo   +81 33 224 5000               4-1 Kioicho
#
#    addressLine2       state    country postalCode territory employeeNumber  \
# 0     Suite 102          MA        USA      02107        NA           1188
# 1     Suite 102          MA        USA      02107        NA           1216
# 2       Level 7                     UK   EC2N 1HN      EMEA           1501
# 3       Level 7                     UK   EC2N 1HN      EMEA           1504
# 4       apt. 5A          NY        USA      10022        NA           1286
# 5       apt. 5A          NY        USA      10022        NA           1323
# 6                               France      75017      EMEA           1102
# 7                               France      75017      EMEA           1337
# 8                               France      75017      EMEA           1370
# 9                               France      75017      EMEA           1401
# 10                              France      75017      EMEA           1702
# 11    Suite 300          CA        USA      94080        NA           1002
# 12    Suite 300          CA        USA      94080        NA           1056
# 13    Suite 300          CA        USA      94080        NA           1076
# 14    Suite 300          CA        USA      94080        NA           1143
# 15    Suite 300          CA        USA      94080        NA           1165
# 16    Suite 300          CA        USA      94080        NA           1166
# 17     Floor #2              Australia   NSW 2010      APAC           1088
# 18     Floor #2              Australia   NSW 2010      APAC           1611
# 19     Floor #2              Australia   NSW 2010      APAC           1612
# 20     Floor #2              Australia   NSW 2010      APAC           1619
# 21               Chiyoda-Ku      Japan   102-8578     Japan           1621
# 22               Chiyoda-Ku      Japan   102-8578     Japan           1625
#
#      lastName firstName extension                            email officeCode  \
# 0    Firrelli     Julie     x2173   jfirrelli@classicmodelcars.com          2
# 1   Patterson     Steve     x4334  spatterson@classicmodelcars.com          2
# 2        Bott     Larry     x2311       lbott@classicmodelcars.com          7
# 3       Jones     Barry      x102      bjones@classicmodelcars.com          7
# 4       Tseng  Foon Yue     x2248      ftseng@classicmodelcars.com          3
# 5      Vanauf    George     x4102     gvanauf@classicmodelcars.com          3
# 6      Bondur    Gerard     x5408     gbondur@classicmodelcars.com          4
# 7      Bondur      Loui     x6493     lbondur@classicmodelcars.com          4
# 8   Hernandez    Gerard     x2028   ghernande@classicmodelcars.com          4
# 9    Castillo    Pamela     x2759   pcastillo@classicmodelcars.com          4
# 10     Gerard    Martin     x2312     mgerard@classicmodelcars.com          4
# 11     Murphy     Diane     x5800     dmurphy@classicmodelcars.com          1
# 12  Patterson      Mary     x4611   mpatterso@classicmodelcars.com          1
# 13   Firrelli      Jeff     x9273   jfirrelli@classicmodelcars.com          1
# 14        Bow   Anthony     x5428        abow@classicmodelcars.com          1
# 15   Jennings    Leslie     x3291   ljennings@classicmodelcars.com          1
# 16   Thompson    Leslie     x4065   lthompson@classicmodelcars.com          1
# 17  Patterson   William     x4871  wpatterson@classicmodelcars.com          6
# 18     Fixter      Andy      x101     afixter@classicmodelcars.com          6
# 19      Marsh     Peter      x102      pmarsh@classicmodelcars.com          6
# 20       King       Tom      x103       tking@classicmodelcars.com          6
# 21      Nishi      Mami      x101      mnishi@classicmodelcars.com          5
# 22       Kato   Yoshimi      x102       ykato@classicmodelcars.com          5
#
#    reportsTo              jobTitle
# 0       1143             Sales Rep
# 1       1143             Sales Rep
# 2       1102             Sales Rep
# 3       1102             Sales Rep
# 4       1143             Sales Rep
# 5       1143             Sales Rep
# 6       1056   Sale Manager (EMEA)
# 7       1102             Sales Rep
# 8       1102             Sales Rep
# 9       1102             Sales Rep
# 10      1102             Sales Rep
# 11                       President
# 12      1002              VP Sales
# 13      1002          VP Marketing
# 14      1056    Sales Manager (NA)
# 15      1143             Sales Rep
# 16      1143             Sales Rep
# 17      1056  Sales Manager (APAC)
# 18      1088             Sales Rep
# 19      1088             Sales Rep
# 20      1088             Sales Rep
# 21      1056             Sales Rep
# 22      1621             Sales Rep

# %% [markdown]
# ## Write 3 Questions of your own and answer them

# %%
# Answers will vary

# %%
# Your code here

# %%
# Your code here

# %%
# Your code here

# %% [markdown]
# ## Level Up: Display the names of each product each employee has sold

# %%
# Your code here

# %% [markdown]
# ## Level Up: Display the Number of Products each employee has sold

# %%
#Your code here

# %% [markdown]
# ## Summary

# %% [markdown]
# Congrats! You now know how to use join statements, along with leveraging your foreign keys knowledge!
